# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Татьяна, привет!</b> Мы рады тебя видеть на территории код-ревьюеров. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У тебя неограниченное количество попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# Проект выполняется в пять этапов:
#
#     1) Изучение данных
#
#     2) Предобработка данных
#
#     3) Добавление необходимых метрик
#
#     4) Анализ данных
#
#     5) Общий вывод
#
# **Цель** данного исследования состоит в том, чтобы проанализировать, какие параметры квартиры влияют на ее конечную стоимость.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Пример можно посмотреть в самом первом проекте (Музыка городов)
# </div>

# %% [markdown]
# <div class="alert alert-info"> Добавила этапы исследования и цель.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# #### Открытие файла

# %%
import pandas as pd
import numpy as np

main_data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# #### Изучение файлов

# %%
main_data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
main_data.hist(figsize=(15, 20))
# Out:
# array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# Такие предупреждения можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib
# 2. В конец кода добавить `;`
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %% [markdown]
# #### Обработка пропущенных значений

# %% [markdown]
# Найдем пропущенные значения по каждому из столбцов.
# Начнем со столбца 'airports_nearest'

# %%
main_data[main_data['airports_nearest'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22            20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30            12   2200000.0       32.80  2018-02-19T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 5              NaN          12.0        14.40      5          NaN  ...
# 8              NaN          27.0        15.43     26          NaN  ...
# 12             NaN           5.0        30.00      5          NaN  ...
# 22            2.75          25.0        30.00     15          NaN  ...
# 30             NaN           9.0          NaN      2          NaN  ...
#
#     kitchen_area  balcony              locality_name  airports_nearest  \
# ...

# %% [markdown]
# В столбце 'airports_nearest' имеются пропущенные значения. Посчитаем количество строк, где есть пропущенные значения в столбце 'airports_nearest'.

# %%
len(main_data[main_data['airports_nearest'].isna()])
# Out:
# 5542

# %% [markdown]
# В датасете 5542 строки, где пропущенно значение в столбце 'airports_nearest'. Данное поле содержит количественную переменную - расстояние в метрах до ближайшего аэропорта. Заполним пропуски в данном столбце медианным значением. Вычислим медианное расстояние до ближайшего аэропорта и вставим в пропущенные ячейки, затем проверим наличие пропущенных значений в столбце:

# %%
main_data['airports_nearest'] = main_data['airports_nearest'].fillna(main_data['airports_nearest'].median())
main_data[main_data['airports_nearest'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Отлично, пропущенные значения в столбце 'airports_nearest' заполнены медианным значением. По такому же принципу проверим оставшиеся столбцы таблицы. На первый взгляд к количественному типу относятся данные в таких столбцах, как: 'balcony', 'ceiling_height', 'cityCenters_nearest', 'days_exposition', 'floor', 'floors_total', 'kitchen_area', 'last_price', 'living_area', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'rooms', 'total_area'.

# %%
main_data[main_data['balcony'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0             2.70          16.0        51.00      8          NaN  ...
# 4             3.03          14.0        32.00     13          NaN  ...
# 5              NaN          12.0        14.40      5          NaN  ...
# 8              NaN          27.0        15.43     26          NaN  ...
# 10            2.67          12.0        20.30      3          NaN  ...
#
#     kitchen_area  balcony              locality_name  airports_nearest  \
# ...

# %%
len(main_data[main_data['balcony'].isna()])
# Out:
# 11519

# %%
main_data['balcony'] = main_data['balcony'].fillna(0)
main_data[main_data['balcony'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Я бы рекомендовал заменить пропуски в балконе на 0. Т.е. веротянее всего, пользовательно тут специально не указал (т.к. у него отсутствует балкон)
# </div>

# %% [markdown]
# <div class="alert alert-info"> Последую совету, спасибо.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Всё верно
# </div>

# %%
main_data[main_data['ceiling_height'].isna()].head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 5            10   2890000.0        30.4  2018-09-10T00:00:00      1
# 6             6   3700000.0        37.3  2017-11-02T00:00:00      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 5             NaN          12.0         14.4      5          NaN  ...
# 6             NaN          26.0         10.6      6          NaN  ...
#
#    kitchen_area  balcony              locality_name  airports_nearest  \
# ...

# %%
len(main_data[main_data['ceiling_height'].isna()])
# Out:
# 9195

# %%
main_data['ceiling_height'] = main_data['ceiling_height'].fillna(main_data['ceiling_height'].median())
main_data[main_data['ceiling_height'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Некоторые столбцы можно поменять на значения, относительно своего района (например высота пололков). Вот так
#
#
# ![image.png](attachment:image.png)
#
# Если хочешь - дарю свой код =)
# </div>

# %%
main_data[main_data['cityCenters_nearest'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22            20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30            12   2200000.0       32.80  2018-02-19T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 5             2.65          12.0        14.40      5          NaN  ...
# 8             2.65          27.0        15.43     26          NaN  ...
# 12            2.65           5.0        30.00      5          NaN  ...
# 22            2.75          25.0        30.00     15          NaN  ...
# 30            2.65           9.0          NaN      2          NaN  ...
#
#     kitchen_area  balcony              locality_name  airports_nearest  \
# ...

# %%
len(main_data[main_data['cityCenters_nearest'].isna()])
# Out:
# 5519

# %%
main_data['cityCenters_nearest'] = main_data['cityCenters_nearest'].fillna(main_data['cityCenters_nearest'].median())
main_data[main_data['cityCenters_nearest'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
main_data[main_data['days_exposition'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0       108.0  2019-03-07T00:00:00      3
# 7              5   7915000.0        71.6  2019-04-18T00:00:00      2
# 44            13   5350000.0        40.0  2018-11-18T00:00:00      1
# 45            17   5200000.0        50.6  2018-12-02T00:00:00      2
# 46            17   6600000.0        52.1  2019-01-31T00:00:00      2
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0             2.70          16.0         51.0      8          NaN  ...
# 7             2.65          24.0          NaN     22          NaN  ...
# 44            2.65          22.0          NaN      3          NaN  ...
# 45            2.65           9.0         30.3      7          NaN  ...
# 46            2.60          24.0         29.7      9          NaN  ...
#
#     kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
len(main_data[main_data['days_exposition'].isna()])
# Out:
# 3181

# %%
main_data['days_exposition'] = main_data['days_exposition'].fillna(main_data['days_exposition'].median())
main_data[main_data['days_exposition'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
main_data[main_data['floor'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# В столбце 'floor' нет пропущенных значений.

# %%
main_data[main_data['floors_total'].isna()].head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12  11640000.0        65.2  2018-10-02T00:00:00      2
# 237              4   2438033.0        28.1  2016-11-23T00:00:00      1
# 457              4   9788348.0        70.8  2015-08-01T00:00:00      2
# 671              4   6051191.0        93.6  2017-04-06T00:00:00      3
# 1757             5   3600000.0        39.0  2017-04-22T00:00:00      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 186             2.65           NaN        30.80      4          NaN  ...
# 237             2.65           NaN        20.75      1          NaN  ...
# 457             2.65           NaN        38.40     12          NaN  ...
# 671             2.65           NaN        47.10      8          NaN  ...
# 1757            2.65           NaN          NaN      9          NaN  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
len(main_data[main_data['floors_total'].isna()])
# Out:
# 86

# %%
main_data['floors_total'] = main_data['floors_total'].fillna(main_data['floors_total'].median())
main_data[main_data['floors_total'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Если пропусков меньше 5-10% их лучше сразу удалить, дабы сэкономить время
# </div>

# %%
main_data[main_data['kitchen_area'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0  64900000.0       159.0  2015-07-24T00:00:00      3
# 30            12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37            10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44            13   5350000.0        40.0  2018-11-18T00:00:00      1
# 59            15   6300000.0        46.5  2017-03-06T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 3             2.65          14.0          NaN      9          NaN  ...
# 30            2.65           9.0          NaN      2          NaN  ...
# 37            2.50           5.0          NaN      1          NaN  ...
# 44            2.65          22.0          NaN      3          NaN  ...
# 59            2.65          13.0          NaN     13          NaN  ...
#
#     kitchen_area  balcony                        locality_name  \
# ...

# %%
len(main_data[main_data['kitchen_area'].isna()])
# Out:
# 2278

# %%
main_data['kitchen_area'] = main_data['kitchen_area'].fillna(main_data['kitchen_area'].median())
main_data[main_data['kitchen_area'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
main_data[main_data['last_price'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# В столбце 'last_price' нет пропущенных значений.

# %%
main_data[main_data['living_area'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0  64900000.0       159.0  2015-07-24T00:00:00      3
# 7              5   7915000.0        71.6  2019-04-18T00:00:00      2
# 30            12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37            10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44            13   5350000.0        40.0  2018-11-18T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 3             2.65          14.0          NaN      9          NaN  ...
# 7             2.65          24.0          NaN     22          NaN  ...
# 30            2.65           9.0          NaN      2          NaN  ...
# 37            2.50           5.0          NaN      1          NaN  ...
# 44            2.65          22.0          NaN      3          NaN  ...
#
#     kitchen_area  balcony                        locality_name  \
# ...

# %%
len(main_data[main_data['living_area'].isna()])
# Out:
# 1903

# %%
main_data['living_area'] = main_data['living_area'].fillna(main_data['living_area'].median())
main_data[main_data['living_area'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
main_data[main_data['parks_around3000'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22            20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30            12   2200000.0       32.80  2018-02-19T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 5             2.65          12.0        14.40      5          NaN  ...
# 8             2.65          27.0        15.43     26          NaN  ...
# 12            2.65           5.0        30.00      5          NaN  ...
# 22            2.75          25.0        30.00     15          NaN  ...
# 30            2.65           9.0        30.00      2          NaN  ...
#
#     kitchen_area  balcony              locality_name  airports_nearest  \
# ...

# %%
len(main_data[main_data['parks_around3000'].isna()])
# Out:
# 5518

# %%
main_data['parks_around3000'] = main_data['parks_around3000'].fillna(main_data['parks_around3000'].median())
main_data[main_data['parks_around3000'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
main_data[main_data['parks_nearest'].isna()].head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1            2.65          11.0        18.60      1          NaN  ...
# 5            2.65          12.0        14.40      5          NaN  ...
# 6            2.65          26.0        10.60      6          NaN  ...
# 7            2.65          24.0        30.00     22          NaN  ...
# 8            2.65          27.0        15.43     26          NaN  ...
#
#    kitchen_area  balcony              locality_name  airports_nearest  \
# ...

# %%
len(main_data[main_data['parks_nearest'].isna()])
# Out:
# 15620

# %%
main_data['parks_nearest'] = main_data['parks_nearest'].fillna(main_data['parks_nearest'].median())
main_data[main_data['parks_nearest'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
main_data[main_data['ponds_around3000'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22            20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30            12   2200000.0       32.80  2018-02-19T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 5             2.65          12.0        14.40      5          NaN  ...
# 8             2.65          27.0        15.43     26          NaN  ...
# 12            2.65           5.0        30.00      5          NaN  ...
# 22            2.75          25.0        30.00     15          NaN  ...
# 30            2.65           9.0        30.00      2          NaN  ...
#
#     kitchen_area  balcony              locality_name  airports_nearest  \
# ...

# %%
len(main_data[main_data['ponds_around3000'].isna()])
# Out:
# 5518

# %%
main_data['ponds_around3000'] = main_data['ponds_around3000'].fillna(main_data['ponds_around3000'].median())
main_data[main_data['ponds_around3000'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
main_data[main_data['ponds_nearest'].isna()].head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1            2.65          11.0        18.60      1          NaN  ...
# 5            2.65          12.0        14.40      5          NaN  ...
# 6            2.65          26.0        10.60      6          NaN  ...
# 7            2.65          24.0        30.00     22          NaN  ...
# 8            2.65          27.0        15.43     26          NaN  ...
#
#    kitchen_area  balcony              locality_name  airports_nearest  \
# ...

# %%
len(main_data[main_data['ponds_nearest'].isna()])
# Out:
# 14589

# %%
main_data['ponds_nearest'] = main_data['ponds_nearest'].fillna(main_data['ponds_nearest'].median())
main_data[main_data['ponds_nearest'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
main_data[main_data['rooms'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# В столбце 'rooms' нет пропущенных значений.

# %%
main_data[main_data['total_area'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# В столбце 'total_area' нет пропущенных значений.
#
# Таким образом, мы заполнили все столбцы с количественным типом. Остались столбцы: 'first_day_exposition', 'is_apartment', 'locality_name', 'open_plan', 'studio', 'total_images'. Из них в булевы значения: 'is_apartment', 'open_plan', 'studio', которые заполнить не представляется возможным, так как нет какого-то четского обоснования тому или иному способу заполнения. В таких случаях, лучше вовсе не заполнять. Посмотрим, есть ли вообще пропуски в этих полях и насколько их много:

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что описывешь ходы действий
# </div>

# %%
print(len(main_data[main_data['is_apartment'].isna()]))
print(len(main_data[main_data['open_plan'].isna()]))
print(len(main_data[main_data['studio'].isna()]))
# Out:
# 20924
# 0
# 0

# %% [markdown]
# Есть пропуски в одном из столбцов с булевым значением - 'is_apartment'. Не представляю возможным заполнение данного поля, к тому же, учитывая процент заполненности данного поля, можно сказать, что это поле не самое важное. Оставим пропущенные значения незаполненными. Остались поля'first_day_exposition', 'total_images', 'locality_name'. Проверим столбцы на наличие пропусков:

# %%
print(len(main_data[main_data['first_day_exposition'].isna()]))
print(len(main_data[main_data['total_images'].isna()]))
print(len(main_data[main_data['locality_name'].isna()]))
# Out:
# 0
# 0
# 49

# %% [markdown]
# Видим, что есть пропуски в столбце 'locality_name'. Посмотрим внимательнее:

# %%
main_data[main_data['locality_name'].isna()]['locality_name'].head()
# Out:
# 1097    NaN
# 2033    NaN
# 2603    NaN
# 2632    NaN
# 3574    NaN
# Name: locality_name, dtype: object

# %% [markdown]
# Самый простой выход, заполнить NaN пустыми строками.

# %%
main_data['locality_name'] = main_data['locality_name'].fillna(value='')
main_data[main_data['locality_name'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# #### Изменение типа данных

# %% [markdown]
# Необходимо произвести изменение типов данных в некоторых столбцах. Самый распространенный случай в датафрейме - вещественный тип данных в тех столбцах, где подразумевается целочисленный. Тип данных в следующих столбцах должен быть изменен с float на int: 'balcony' (балконов не может быть 1.5), 'days_exposition' (дней не может быть 1.5 по постановке задачи), 'floors_total' (количество этажей не может быть 1.5), 'parks_around3000' и 'ponds_around3000' (количество парков и прудов не может быть 1.5). ТАкже надо привести дату в поле 'first_day_exposition' к читабельному виду (убрать разделитель 'T'), и, наконец, поле 'is_apartment', исходя из описания, имеет тип bool, а не object. Произведем изменения:

# %%
main_data['balcony'] = main_data['balcony'].astype(int)
main_data['balcony']
# Out:
# 0        0
# 1        2
# 2        0
# 3        0
# 4        0
#         ..
# 23694    0
# 23695    0
# 23696    0
# 23697    2
# 23698    0
# Name: balcony, Length: 23699, dtype: int64

# %%
main_data['days_exposition'] = main_data['days_exposition'].astype(int)
main_data['days_exposition']
# Out:
# 0         95
# 1         81
# 2        558
# 3        424
# 4        121
#         ...
# 23694     95
# 23695     45
# 23696     95
# 23697    602
# 23698     95
# Name: days_exposition, Length: 23699, dtype: int64

# %%
main_data['floors_total'] = main_data['floors_total'].astype(int)
main_data['floors_total']
# Out:
# 0        16
# 1        11
# 2         5
# 3        14
# 4        14
#          ..
# 23694     5
# 23695     5
# 23696     3
# 23697    17
# 23698     5
# Name: floors_total, Length: 23699, dtype: int64

# %%
main_data['parks_around3000'] = main_data['parks_around3000'].astype(int)
main_data['parks_around3000']
# Out:
# 0        1
# 1        0
# 2        1
# 3        2
# 4        2
#         ..
# 23694    1
# 23695    0
# 23696    0
# 23697    2
# 23698    0
# Name: parks_around3000, Length: 23699, dtype: int64

# %%
main_data['ponds_around3000'] = main_data['ponds_around3000'].astype(int)
main_data['ponds_around3000']
# Out:
# 0        2
# 1        0
# 2        2
# 3        3
# 4        1
#         ..
# 23694    3
# 23695    1
# 23696    1
# 23697    3
# 23698    1
# Name: ponds_around3000, Length: 23699, dtype: int64

# %%
main_data['first_day_exposition'] = pd.to_datetime(main_data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
main_data['first_day_exposition']
# Out:
# 0       2019-03-07
# 1       2018-12-04
# 2       2015-08-20
# 3       2015-07-24
# 4       2018-06-19
#            ...
# 23694   2017-03-21
# 23695   2018-01-15
# 23696   2018-02-11
# 23697   2017-03-28
# 23698   2017-07-21
# Name: first_day_exposition, Length: 23699, dtype: datetime64[ns]

# %% [markdown]
# Чтобы не заменить пропущенные значения значением False  в столбце 'is_apartment', оставим тип object, но заменим значащие ячейки след. образом:

# %%
main_data['is_apartment'] = main_data['is_apartment'].replace({'True': True, 'False': False}, inplace=True)
main_data['is_apartment']
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 23694    None
# 23695    None
# 23696    None
# 23697    None
# 23698    None
# Name: is_apartment, Length: 23699, dtype: object

# %% [markdown]
# #### Устранение дубликатов

# %% [markdown]
# Проанализируем датафрейм на явные дубликаты.

# %%
main_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на дубликаты - основа предобработки данных
# </div>

# %% [markdown]
# Явных дублей нету. По поставновке задачи, проанализируем столбец 'locality_name' на наличие неявных дублей.И приведем значения к одному виду. Выведем список уникальных значений.

# %%
set(main_data['locality_name'])
# Out:
# {'',
#  'Бокситогорск',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Высоцк',
#  'Гатчина',
#  'Зеленогорск',
#  'Ивангород',
#  'Каменногорск',
#  'Кингисепп',
#  'Кириши',
#  'Кировск',
#  'Колпино',
#  'Коммунар',
#  'Красное Село',
#  'Кронштадт',
#  'Кудрово',
#  'Лодейное Поле',
#  'Ломоносов',
#  'Луга',
#  'Любань',
#  'Мурино',
#  'Никольское',
#  'Новая Ладога',
#  'Отрадное',
#  'Павловск',
#  'Петергоф',
#  'Пикалёво',
#  'Подпорожье',
#  'Приморск',
#  'Приозерск',
#  'Пушкин',
#  'Санкт-Петербург',
#  'Светогорск',
#  'Сертолово',
#  'Сестрорецк',
#  'Сланцы',
#  'Сосновый Бор',
#  'Сясьстрой',
#  'Тихвин',
#  'Тосно',
#  'Шлиссельбург',
#  'городской поселок Большая Ижора',
#  'городской поселок Янино-1',
#  'городской посёлок Будогощь',
#  'городской посёлок Виллози',
#  'городской посёлок Лесогорский',
#  'городской посёлок Мга',
#  'городской посёлок Назия',
#  'городской посёлок Новоселье',
#  'городской посёлок Павлово',
# ...

# %% [markdown]
# Основная проблема заключается в том, что есть строки с добавлением типа населенного пункта, что избыточно и заполняются типы по-разному. Удалим описанием типа населенного пункта и оставим только названия.

# %%
stopwords= ['село', 'садовое', 'товарищество', 'городской', 'посёлок', 'поселок', 'типа', 'городского', 'деревня']
lst = main_data['locality_name']

nw_lst = []
 
for row in lst:
    x = str(row)
    y = x.split()
    resultwords  = [word for word in y if word not in stopwords]
    result = ' '.join(resultwords)
    nw_lst.append(result)

main_data['name_new'] = nw_lst

main_data[['locality_name', 'name_new']]
# Out:
#              locality_name         name_new
# 0          Санкт-Петербург  Санкт-Петербург
# 1           посёлок Шушары           Шушары
# 2          Санкт-Петербург  Санкт-Петербург
# 3          Санкт-Петербург  Санкт-Петербург
# 4          Санкт-Петербург  Санкт-Петербург
# ...                    ...              ...
# 23694      Санкт-Петербург  Санкт-Петербург
# 23695                Тосно            Тосно
# 23696     село Рождествено      Рождествено
# 23697      Санкт-Петербург  Санкт-Петербург
# 23698  поселок Новый Учхоз      Новый Учхоз
#
# [23699 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличный код
# </div>

# %% [markdown]
# <div class="alert alert-info"> :))))))))))))))</div>

# %% [markdown]
# Перезапишем поле 'locality_name' и присвоим ему значения поля 'name_new'.

# %%
main_data['locality_name'] = main_data['name_new']
main_data['locality_name']
# Out:
# 0        Санкт-Петербург
# 1                 Шушары
# 2        Санкт-Петербург
# 3        Санкт-Петербург
# 4        Санкт-Петербург
#               ...
# 23694    Санкт-Петербург
# 23695              Тосно
# 23696        Рождествено
# 23697    Санкт-Петербург
# 23698        Новый Учхоз
# Name: locality_name, Length: 23699, dtype: object

# %% [markdown]
# #### Устранение аномалий

# %% [markdown]
# Неявные дубликаты в поле устранены. Посмотрим на аномалии в значениях числовых полей датафрейма.

# %%
import matplotlib.pyplot as plt

for_check = ['airports_nearest', 'balcony', 'ceiling_height', 'cityCenters_nearest', 'days_exposition', 'floor', 'floors_total', 'kitchen_area', 'last_price', 'living_area', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'rooms', 'total_area', 'total_images']

for column in for_check:
    plt.figure()
    main_data.boxplot([column])

# %% [markdown]
# Исходя из построенных диаграмм, можно сказать, что аномалии наблюдаются в таких полях, как: 'ceiling_height', 'last_price', 'total_area'. Устраним аномалии. В поле 'ceiling_height' наблюдается аномалия, обусловленная человеческим фактором. Скорее всего, значения от 20 до 60 - можно принять за опечатку. И смело разделить на 10. В теории, даже самый высокий потолок в квартирах СПб врят ли будет больше 6 метров, поэтму значения от 6 до 20 метров - ошибочны. Так как идей, как их устранить нет, то заменим значения NaN, а после всех исправлений - медианой. Также поступим со значениями от 60 до 100. Значения от 0 до 2 также являются аномалией, так как в жизни такие потолки в нормальной жилой квартире увидеть сложно.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что  проверяешь данные не "на глаз". Лучше посмотреть на выбросы и аномалии данных математически, и удалить их с помощью специального метода boxplot()

# %%
list = []
for elem in main_data['ceiling_height']:
    if 0 <=elem < 2 or 6 <= elem < 20 or 60 <= elem <= 100:
        list.append(None)
    elif 20 <= elem < 60:
        list.append(elem/10)
    else: list.append(elem)
main_data['ceiling_height'] = list
main_data['ceiling_height'] = main_data['ceiling_height'].fillna(main_data['ceiling_height'].median())
main_data.boxplot('ceiling_height')
# Out:
# <AxesSubplot:>

# %% [markdown]
# В поле 'last_price', 'total_area' удалим выбивающиеся значения. Можно удалить выбивающиеся значения, например, квартира, стоимостью 80 млн руб для СПб скорее редкость, возможно это пентхаус. Можно пренебречь. Оставить предельным значением стоимости квартиры значение 40 млн. Это соответсвует крупным квартирам в центре города, находящимся в старом жилом фонде или квартирам в районе Крестовского острова. В столбце 'total_area' удалим выбивающиеся значения. По статистике, даже самые максимальные площади квартир в СПб - это порядка 600 кв.м., все остальное не похоже на реальную картину или это помещение уже не назовешь "квартира". Поэтому ограничим площадь значением 600 кв.м. Постром диаграмму размаха для наглядности изменений. Для того, чтобы исключить NaN, полученные Null значения заменим на медиану.

# %%
list = []
for elem in main_data['last_price']:
    if elem <= 40000000:
        list.append(elem)
    else: list.append(None)
main_data['last_price'] = list
main_data['last_price'] = main_data['last_price'].fillna(main_data['last_price'].median())

list = []
for elem in main_data['total_area']:
    if elem <= 600:
        list.append(elem)
    else: list.append(None)
main_data['total_area'] = list
main_data['total_area'] = main_data['total_area'].fillna(main_data['total_area'].median())

columns = ['last_price', 'total_area']
for column in columns:
    plt.figure()
    main_data.boxplot([column])

# %% [markdown]
# Аномалии устранены. Предобработку данных можно считать завершенной.

# %%
main_data['ceiling_height'].unique()
# Out:
# array([2.7 , 2.65, 3.03, 2.5 , 2.67, 2.56, 3.05, 2.75, 2.6 , 2.9 , 2.8 ,
#        2.55, 3.  , 3.2 , 2.61, 3.25, 3.45, 2.77, 2.85, 2.64, 2.57, 4.15,
#        3.5 , 3.3 , 2.71, 4.  , 2.47, 2.73, 2.84, 3.1 , 2.34, 3.4 , 3.06,
#        2.72, 2.54, 2.51, 2.78, 2.76, 2.58, 3.7 , 2.52, 5.2 , 2.87, 2.66,
#        2.59, 2.  , 2.45, 3.6 , 2.92, 3.11, 3.13, 3.8 , 3.15, 3.55, 3.16,
#        3.62, 3.12, 2.53, 2.74, 2.96, 2.46, 5.3 , 5.  , 2.79, 2.95, 4.06,
#        2.94, 3.82, 3.54, 3.53, 2.83, 4.7 , 2.4 , 3.38, 3.01, 5.6 , 3.65,
#        3.9 , 3.18, 3.35, 2.3 , 3.57, 2.48, 2.62, 2.82, 3.98, 2.63, 3.83,
#        3.52, 3.95, 3.75, 2.88, 3.67, 3.87, 3.66, 3.85, 3.86, 4.19, 3.24,
#        4.8 , 4.5 , 4.2 , 3.36, 3.08, 3.68, 3.07, 3.37, 3.09, 3.26, 3.34,
#        2.81, 3.44, 2.97, 3.14, 4.37, 2.68, 3.22, 3.27, 4.1 , 2.93, 3.46,
#        3.47, 3.33, 3.63, 3.32, 2.98, 2.86, 3.17, 4.4 , 3.28, 3.04, 4.45,
#        5.5 , 3.84, 3.23, 3.02, 3.21, 3.43, 3.78, 4.3 , 3.39, 2.69, 3.31,
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Второй раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим следующие столбцы в датафрейм:
#
# 1) цена квардратного метра - 'metr_price'
#
# 2) день публикации объявления - 'weekday_exposition'
#
# 3) месяц публикации - 'month_exposition'
#
# 4) год публикации - 'year_exposition'
#
# 5) тип этажа квартиры - 'floor_type'
#
# 6) расстояние в км до центра города - 'center_distance_km'

# %%
import numpy as np #надо для определения типа этажа

main_data['metr_price'] = main_data['last_price']/main_data['total_area']
main_data['weekday_exposition'] = main_data['first_day_exposition'].dt.dayofweek
main_data['month_exposition'] = main_data['first_day_exposition'].dt.month
main_data['year_exposition'] = main_data['first_day_exposition'].dt.year
main_data['floor_type'] = np.where(main_data['floor'] == 1,'Первый', np.where(main_data['floor'] == main_data['floors_total'], 'Последний', 'Другой'))
main_data['center_distance_km'] = round(main_data['cityCenters_nearest']/1000)

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#     https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует округление км. Поправишь, пожалуйста?
# </div>

# %% [markdown]
# <div class="alert alert-info"> Поправила. В изначальной версии, который Юпитер мне не сохранил, я в конце, когда последнее задание делала, округляла это поле. Но увы, ничего не сохранилось</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Странно. Возможно ты не пересохранила проект перед отправкой
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# Рассчитаны и добавлены необходимые метрики.

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучение и описание параметров

# %% [markdown]
# Изучим каждый из наиболее интересных параметров с помощью гистограмм. Сделаем выводы по отдельно взятым апраметрам. Начнем с общей площади квартиры.

# %%
main_data['total_area'].plot(kind='hist', range=(0,100))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Я бы советовал сократить range и тогда мы сможем увидеть пиковые значения.
# </div>

# %% [markdown]
# <div class="alert alert-info">Хорошо, поправила.</div>

# %% [markdown]
# Больше 50% объявлений описывают квартиры площадью до 50 кв. м.

# %%
main_data['living_area'].plot(kind='hist', range=(0,100))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# У большинства объявлений жилая площадь составляет не более 35 кв.м.

# %%
main_data['kitchen_area'].plot(kind='hist', range=(0,30))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Площадь кухни у большинства объявлений находится в пределах 10 кв.м. По площадям помещений, можно сказать, что большинство квартир соответствует стандартной картине на рынке недвижимости. А также площади помещений коррелируют друг с другом, чем больше, в целом, площадь квартиры, тем больше жилая площадь и площадь кухни.

# %%
main_data['last_price'].plot(kind='hist', range=(0,15000000))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Больше всего в СПб и ЛО квартир стоимостью около 5 млн рублей.

# %%
main_data['rooms'].plot(kind='hist', range=(0,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Наиболее популярны в продаже однокомнатные и двухкомнатные, а затем трехкомнатные. Данные позиции составляют большинство от объявлений.

# %%
main_data['ceiling_height'].plot(kind='hist', range=(2,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Высота потолков в квартир чаще всего составляет 2-2,5 метра.

# %%
main_data['floor'].plot(kind='hist', range=(0,15))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Больше 80% объявлений описывают квартиру ниже 11 этажа, из них больше всего квартир находится на 2-7 этажах.

# %%
main_data['floor_type'].value_counts().sort_index(ascending=True).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Квартир на первых и последних этажах примерно одинаково, но не составляют и 50% выборки. Большинство квартир находятся не на 1 и последнем этажах.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %% [markdown]
# <div class="alert alert-info"> Здорово. Везде добавила range</div>

# %%
main_data['floors_total'].plot(kind='hist', range=(0,20))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Больше 50% объявлений расположено в домах, где не больше 11 этажей. Это коррелирует и с частотой объявлений по этажу. В СПб, в целом, ввиду исторических особенностей, больше домов низкой постройки. Высотки строятся ближе к окраине. А здание в 37 этажей (самое высокое) и вовсе одно. В 30 тоже редкость. При этом более встречаемое значение - 4-5 этажей. Соответствует реальному положению дел.

# %%
main_data['cityCenters_nearest'].plot(kind='hist', range=(0,20000))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большая часть недвижимости расположена в пределах 15 км от центра. Это объясняет то, что большая часть квартир находится в относительно малоэтажных зданиях. Чем дальше от центра, тем выше этажность домов. Из них, большая часть приходится на расстояние в 13 км от центра. Это золотая середина в СПб - районы Московский, Красногвардейский и т.д. Не очень далеко, но и не близко.

# %%
main_data['airports_nearest'].plot(kind='hist', range=(0,40000))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Аэропорт в СПб и ЛО один - Пулково. Если учесть предыдущие выводы по приблизительном расположении квартир, то так и получается, что относительно аэропорта большинство квартир будет расположено где-то от 15 до 35 км. Чем ближе к югу, тем ближе к аэропорту. Кстати, отсюда можно сделать вывод, что квартир для продажи больше на севере города. Из них большая часть расположена в 25 км от аэропорта. Так как аэропорт находится на юге СПб, можно предположить, что большая часть объявлений ближе к северу СПб.

# %%
main_data['parks_nearest'].plot(kind='hist', range=(0,700))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# В СПб и ЛО очень много парковых зон. Поэтому неудивительно, что большая часть квартир имеет недалеко парковую зону.

# %%
main_data['weekday_exposition'].value_counts().sort_index(ascending=True).plot.bar()
# Out:
# <AxesSubplot:>

# %%
main_data['month_exposition'].value_counts().sort_index(ascending=True).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Больше всего объявлений в будни, скорее всего, в часы работы риелторов. Ближе к новому году и в начале года обявлений больше, возможно, обусловенно психологическими причинами - люди стараются что-то менять.
#
# Таким образом проанализированы и описаны основные параметры.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# В мае не до продаж, все на огородах =)
# </div>

# %% [markdown]
# #### Как быстро продавались квартиры?

# %% [markdown]
# Изучим, как быстро продавались квартиры. Для этого построим гистограмму по данному параметру, а также посчитаем среднее и медиану и сделаем необходимые выводы.

# %%
main_data['days_exposition'].plot(kind='hist', bins = 200,  range=(0,200))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Давай тут уменьшим range до 100 или 200 (ведь именно в эти дни происходят основные продажи), возможно тут есть интересные аномалии. Так же в таких моментах лучше делать колличество корзин = колличеству дней (в соответствии с range)
# </div>

# %% [markdown]
# <div class="alert alert-info"> Done</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Практически верно, но не были заданы корзины (bins). Поправил код. Теперь если не брать мединное значние (ведь на него мы заменили 10к пропусков), то аномалии видны на 45 и 60 дни
# </div>

# %%
print(round(main_data['days_exposition'].mean()),',', round(main_data['days_exposition'].median()))
# Out:
# 169 , 95

# %% [markdown]
# Обычно продажа занимает 95 дней. Но среднее показывает, что есть ситуации, когда продажа квартиры занимает намного больше. Это видно из гистограммы. Среднее значение не устойчиво к выбросам, а выбросы здесь есть. Исходя из полученных значений, можно сказать, что продажа длиною в 150 дней уже будет необычайно долгой, а продажа меньше, чем за месяц - быстрой.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# да, меньше месяца можно назвать быстрой продажей
# </div>

# %% [markdown]
# #### Какие факторы больше всего влияют на общую стоимость жилья?

# %% [markdown]
# Проанализируем, какие факторы больше всего влияют на общую (полную) стоимость объекта. Построим графики, которые покажут корреляцию цены от следующих параметров: общая площадь, жилая площадь, площадь кухни, количество комнат, типа этажа, даты размещения (день недели, месяц, год).

# %%
print(main_data['last_price'].corr(main_data['total_area']))
print(main_data.plot(x='last_price', y='total_area', kind='scatter'))
# Out:
# 0.6685470565617863
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Слабая корреляция между площадью квартиры и стоимость прослеживается.

# %%
print(main_data['last_price'].corr(main_data['living_area']))
print(main_data.plot(x='last_price', y='living_area', kind='scatter'))
# Out:
# 0.5609690038861279
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Слабая корреляция между жилой площадью и стоимость прослеживается.

# %%
print(main_data['last_price'].corr(main_data['kitchen_area']))
print(main_data.plot(x='last_price', y='kitchen_area', kind='scatter'))
# Out:
# 0.5085242797958034
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Слабая корреляция между площадью кухни и стоимостью квартиры прослеживается.

# %%
print(main_data['last_price'].corr(main_data['rooms']))
print(main_data.plot(x='last_price', y='rooms', kind='scatter'))
# Out:
# 0.49847001219914977
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Нет корреляции между количеством комнат и стоимостью квартир. Следующие графики построим с помощью pyplot, так как величины не количественные.

# %%
import matplotlib.pyplot as plt

plt.bar(main_data['floor_type'], main_data['last_price'])
# Out:
# <BarContainer object of 23699 artists>

# %% [markdown]
# Видно, что этаж на стоимость не влияет.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Да, первый этаж дешевле всех
# </div>
# </div>

# %%
plt.bar(main_data['weekday_exposition'], main_data['last_price'])
# Out:
# <BarContainer object of 23699 artists>

# %% [markdown]
# Видно, что день недели на стоимость не влияет.

# %%
plt.bar(main_data['month_exposition'], main_data['last_price'])
# Out:
# <BarContainer object of 23699 artists>

# %% [markdown]
# Видно, что месяц продажи на стоимость не влияет.

# %%
plt.bar(main_data['year_exposition'], main_data['last_price'])
# Out:
# <BarContainer object of 23699 artists>

# %% [markdown]
# Видно, что год на стоимость не влияет. Единственное, в 2014 был спад продаж, но это был неспокойный год - кризис.

# %% [markdown]
# Можно сказать, что корреляция цены прослеживается только с площадью квартиры, и в частности, с жилой площадью.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Лучше после каждого графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи - так проще читать проект, поскольку будущим коллегам или заказчику не надо будет самим интерпретировать результаты каждого теста или графика.
# </div>

# %% [markdown]
# <div class="alert alert-info">Добавила вывод по каждому графику зависмости цены от параметров.</div>

# %% [markdown]
# #### Как меняется цена в зависимости от населенного пункта?

# %% [markdown]
# Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
average_price_local = pd.pivot_table(main_data, index='locality_name', values='metr_price', aggfunc={'mean', 'count'})
average_price_local = average_price_local.sort_values(by='count', ascending=False)
average_price_local.head(10)
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  15721  110687.968614
# Мурино             590   86087.512050
# Кудрово            472   95324.930544
# Шушары             440   78677.364217
# Всеволожск         398   68654.473986
# Пушкин             369  102854.816581
# Колпино            338   75424.579098
# Парголово          327   90175.913458
# Гатчина            307   68746.146763
# Выборг             237   58141.909153

# %% [markdown]
# В десятку самых популярных мест продажи входят СПб и ближайшие крупные населенные пункты. Думаю потому, что застройка там активная и есть, что продавать.

# %%
average_price_local_max = average_price_local.sort_values(by='mean', ascending=False)
average_price_local_max.head(1)
# Out:
#                count           mean
# locality_name
# Зеленогорск       24  115122.799198

# %% [markdown]
# Самая дорогая недвижимость в Зеленогорске. Так и есть. Это очень маленький, спокойный, чистый (и в плане экологии) городок, вокруг которого лес и еще прямой выход к Финскому заливу.

# %%
average_price_local_min = average_price_local.sort_values(by='mean', ascending=True)
average_price_local_min.head(1)
# Out:
#                count          mean
# locality_name
# Старополье         3  11206.221198

# %% [markdown]
# В Старополье самая дешевая недвижимость в данной выборке. Старополье - это деревушка, очень удаленная от крупных населенных центров, поэтому низкая стоимость вполне очевидна.

# %% [markdown]
# #### Как меняется цена в зависимости от расстояния до центра Санкт-Петербурга?

# %% [markdown]
# Ранее было посчитано расстояние до центра в километрах. Теперь выделим квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислим среднюю цену каждого километра. Сделаем вывод о том, как стоимость объектов зависит от расстояния до центра города

# %%
spb_center = main_data.loc[main_data['locality_name']=='Санкт-Петербург'].pivot_table(index='center_distance_km', values='last_price', aggfunc={'mean'})
spb_center['mean'] = spb_center['mean']/1000000
spb_center
# Out:
#                          mean
# center_distance_km
# 0.0                 13.483613
# 1.0                 12.013604
# 2.0                 11.463452
# 3.0                 10.025438
# 4.0                 10.869817
# 5.0                 11.273785
# 6.0                 10.532293
# 7.0                 10.201576
# 8.0                  9.015338
# 9.0                  6.950659
# 10.0                 6.504119
# 11.0                 6.135535
# 12.0                 5.828545
# 13.0                 6.314708
# 14.0                 5.629101
# 15.0                 5.884751
# 16.0                 5.373131
# 17.0                 5.241014
# 18.0                 5.091331
# 19.0                 5.037675
# 20.0                 5.951465
# 21.0                 5.493469
# 22.0                 5.415524
# 23.0                 4.985376
# 24.0                 3.854430
# 25.0                 4.052840
# 26.0                 3.973013
# 27.0                 8.300000
# 28.0                 5.026429
# ...

# %% [markdown]
# Конечно, чем меньше расстояние от центра города, тем выше стоимость квартиры. Для наглядности построим график зависимости и рассчитаем корреляцию, где по всей логике, должна получиться отрицательная зависимость.

# %%
spb_center['distance'] = spb_center.index
print(spb_center['mean'].corr(spb_center['distance']))
spb_center.plot(y='mean', x='distance', kind='scatter', title = 'Заголовок');
# Out:
# -0.8479393649887627

# %% [markdown]
# Есть сильная отрицательная зависимость цены жилья и удаленности от центра города.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Ошибка в коде, ядро умирает. Лучше перед отправкой проекта, его стоит прогнать на платформе ЯП, во ихбежания конфликтов библиотек.
# </div>

# %% [markdown]
# <div class="alert alert-info">Все сделала изначально. Отправила Вам на проверку, но увы, Юпитер не сохранил изменения. Обидно, Больно, Но ладно</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличная визуализация. В твой код добавил заголовок, посмотри, пожалуйста, этот момент. Очень важно оформлять графики
#
# Смотри, как можно в одну строку
# </div>

# %%
main_data[main_data['locality_name'] == 'Санкт-Петербург'].groupby('center_distance_km')['last_price'].mean().plot(figsize = (20, 8));

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует шаг 4.5. Давай сделаем проект сильнее, и сделаем сводную таблицу (удалённость в км от центра Питера, и средняя цена на этом км). И уже по этой сводной таблице построим линейную диграмму для визуализации динамики цены относительно удалённости
# </div>

# %% [markdown]
# <div class="alert alert-info">Давай, восстановила работу :)</div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует финальный вывод. Ошибка при выгрузке?
#     </div>

# %% [markdown]
# <div class="alert alert-info">Да, увы, ошибка.  Юпитер не все сохранил вчера :(
#
#     Не все предложения ввела в проект, но максимально сделала. Просто вот оно как получилось, а еще сборный проект. Надо поторопиться. Но я все посмотрела, спасибо за советы.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер) Всё чётко и лаконично. Принимаю проекты по-быстрее) Не стану задерживать =)
# </div>

# %% [markdown]
# **Общая картина:** В выборке большинство квартир соответствуют такой "среднестатистической" квартире в СПб. Площадь около 50 кв.м, из них жилая - около 30-35, кухня - около 10, комнат обычно 2, потолки стандартные 2-2,5 метра, находятся не высоко - до 11 этажа, чаще всего от 2 до 7 в малоэтажных зданиях, что соответствует реальности, так как в СПб и ЛО, в среднем, дома невысокие. Чаще всего квартиры в 15 км от центра и в 25 км от аэропорта, если посмотреть на карту СПб, то можно сказать, что квартиры, вероятнее всего, расположены либо в восточной части, либо в северной. От огромного большинства квартир недалеко парковая зона, в СПБ и ЛО много парков, поэтому тут очевидно. Чаще всего объявления публикуются в будни, вероятно, из-за часов работы риелторов, а также ближе к НГ и после него, вероятно, обусловлено психологическими факторами, люди склонны менять что-то в жизни в этот период. В мае продажи падают - люди уезжают отдыхать или на дачу, в январе такая же ситуация - люди тоже отдыхают.
# Также можно сказать, что квартиры в среднем продаются за 95 дней, поэтому продажи длительностью меньше 30 и больше 150 дней можно считать необычайно быстрыми и долгими, соответственно. Больше всего объявлений приходится на СПб и близжайшие крупные населенные пункты. Самая дорогая недвижимость при этом в Зеленогорске - объясняется расположением, а самая дешевая - в Старополье, что также объясняется расположением и величиной населенного пункта.
#
# **Зависимость стоимости квартиры от параметров:** На общую стоимость жилья несильно, но влияет площадь квартиры, в частности ее жилая площадь, площадь кухни влияет уже очень слабо. Больше всего на площадь квартиры в СПб влияет ее удаленность от центра города. Центральный район СПб очень красивый и очень дорогой, также там развита вся инфораструктура. Конечно, стоимость жилья там высока.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Округление - **done**
#
# 2) Ошибка в коде - **done**
#
# 3) Отсутствуют шаги заданий - **done**
#
# 4) Уменьшить range, чтобы рассмотреть пики - **done**
#
# 5) Отсутствует решение по 4.5 - **done**
#
# 6) Финальный вывод - **done**
#
# 7) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи - **done**
#
# 8) Подправить выводы, после изменений - **done**
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
